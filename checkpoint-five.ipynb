# %% [markdown]
# # Checkpoint Five: Modeling Data
#
# With your visualizations ready to go, the final step in your project is to do some predictive analysis on your dataset. You will be using linear regression for your model. You will not be penalized if your linear regression model does not work out. You just need to build the model and make notes as to the results.
#
# Link to my dataset:
#
# [Top 850 Guitar Tabs | Kaggle](https:\www.kaggle.com\datasets\thomaskonstantin\top-850-guitar-tabs)
#
# ## Prepare Your Dataframe
#
# Import any libraries you need and create a dataframe.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import statsmodels.api as sm 
sns.set_style('darkgrid')
sns.set(font_scale=1.5)

df1 = pd.read_csv('guitarDB.csv')

df1.info()
df1.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 850 entries, 0 to 849
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Artist       850 non-null    object
#  1   Song Name    850 non-null    object
#  2   Song Rating  850 non-null    object
#  3   Song Hits    850 non-null    object
#  4   Page Type    850 non-null    object
#  5   Difficulty   850 non-null    object
#  6   Key          850 non-null    object
#  7   Capo         850 non-null    object
#  8   Tuning       850 non-null    object
# dtypes: object(9)
# memory usage: 59.9+ KB
#          Artist           Song Name Song Rating   Song Hits Page Type  \
# 0  Jeff Buckley         Hallelujah       40,045  31,174,526    Chords
# 1    Ed Sheeran             Perfect      31,694  25,794,778    Chords
# 2   John Legend           All Of Me      20,169  25,653,362    Chords
# 3     Passenger          Let Her Go      17,267  24,556,593    Chords
# ...

# %% [markdown]
# ## Find Correlations
#
# Use either pairplot or a heatmap or both to find the two variables with the strongest correlation in your dataset.

# %%
sns.pairplot(df1, x_vars= ['Song Hits', 'Key', 'Song Rating'], y_vars='Capo', height=6, aspect=1, kind='scatter')
plt.show()
sns.pairplot(df1, x_vars= ['Artist', 'Page Type', 'Song Rating'], y_vars='Key', height=6, aspect=1, kind='scatter')
plt.show()

# %% [markdown]
# ## Create Your Model
#
# Use the two columns with the strongest correlation to create and train your model. Make sure to print out the summary and plot the column values and the line produced by the model.

# %%
X = df1['Song Hits']
y = df1['Capo']
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 1, test_size = 4, random_state = 100)
X_train_A = sm.add_constant(X_train)
lr= sm.OLS(y_train, X_train_A).fit()
lr.params
lr.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 5
#       3 X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 1, test_size = 4, random_state = 100)
#       4 X_train_A = sm.add_constant(X_train)
# ----> 5 lr= sm.OLS(y_train, X_train_A).fit()
#       6 lr.params
#       7 lr.summary()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\statsmodels\regression\linear_model.py:922, in OLS.__init__(self, endog, exog, missing, hasconst, **kwargs)
#     919     msg = ("Weights are not supported in OLS and will be ignored"
#     920            "An exception will be raised in the next version.")
#     921     warnings.warn(msg, ValueWarning)
# --> 922 super(OLS, self).__init__(endog, exog, missing=missing,
#     923                           hasconst=hasconst, **kwargs)
#     924 if "weights" in self._init_keys:
# ...

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, a + b*X_train, 'r')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 2
#       1 plt.scatter(X_train, y_train)
# ----> 2 plt.plot(X_train, a + b*X_train, 'r')
#       3 plt.show()
#
# NameError: name 'a' is not defined

# %% [markdown]
# ## Error Terms
#
# Finally, plot your error terms!

# %% [markdown]
# ## Summarize Your Work
#
# Make notes of your answers to the questions below.
#
# 1. What was your R-squared value? 0.638
# 2. Based on your results, do you think a linear regression model was the best type of predictive analysis for your dataset? It was not particularly effective in this case.
# 3. Was your plot of the error terms a bell curve? Not really
